[16,4,2,25,26],
[16,5,1,27],
[16,6,1,29],
[17,1,1,20],
[17,4,1,28],
[17,5,1,29],
[17,6,1,30],
[17,7,1,31],
[18,2,1,24],
[18,3,1,26],
[18,4,1,27],
[18,6,1,30],
[18,7,1,31],
[19,1,1,22],
[19,2,1,24],
[19,3,1,26],
[19,4,1,28],
[19,5,1,29],
[19,6,1,30],
[19,7,1,31],
[20,4,1,29],
[20,6,1,31],
[21,1,1,23],
[21,2,2,25,26],
[21,3,1,27],
[21,6,1,31],
[22,2,1,26],
[22,4,1,29],
[22,6,1,31],
[23,2,2,27,28],
[23,3,1,29],
[23,4,1,30],
[23,5,1,31],
[24,1,1,26],
[24,4,1,30],
[24,5,1,31],
[25,1,1,27],
[25,2,1,29],
[25,4,1,31],
[26,4,1,31],
[27,2,1,30],
[27,3,1,31],
[28,1,1,29],
[28,2,1,30],
[28,3,1,31],
[29,2,1,31],
[30,1,1,31],
]

# %%
from collections import defaultdict
cells_num = defaultdict(int)
for c in cells:
    cells_num[c] += 1
cells_v2 = []
cells_count = defaultdict(int)
for c in cells:
    cells_v2.append(c if cells_num[c] == 1 else [c, cells_count[c]])
    cells_count[c] += 1
cells_v2
# Out:
# [0,
#  1,
#  2,
#  [3, 0],
#  [3, 1],
#  [4, 0],
#  [4, 1],
#  [5, 0],
#  [5, 1],
#  [6, 0],
#  [6, 1],
#  [6, 2],
#  [7, 0],
#  [7, 1],
#  [7, 2],
#  [8, 0],
#  [8, 1],
#  [9, 0],
#  [9, 1],
#  [9, 2],
#  [10, 0],
#  [10, 1],
#  [10, 2],
#  [11, 0],
#  [11, 1],
#  [12, 0],
#  [12, 1],
#  [13, 0],
#  [13, 1],
#  14,
#  15,
#  16]

# %%
ops_v2 = []
for op in ops:
    if op[1] in [1, 2, 4, 8, 16]:
        ops_v2.append([cells_v2[op[0]], (([cells_v2[op[3]][0]] + [cells_v2[i][1] for i in op[3:]]) if type(c1 := cells_v2[op[3]]) is list else c1)])
ops_v2
# Out:
# [[0, 1],
#  [0, 2],
#  [0, [4, 0]],
#  [1, [3, 0, 1]],
#  [1, [5, 0, 1]],
#  [1, [9, 0]],
#  [2, [3, 0]],
#  [2, [4, 1]],
#  [2, [6, 0, 1, 2]],
#  [2, [10, 1]],
#  [[3, 0], [5, 1]],
#  [[3, 0], [7, 0, 2]],
#  [[3, 0], [11, 0, 1]],
#  [[3, 1], [4, 1]],
#  [[3, 1], [5, 1]],
#  [[3, 1], [7, 1]],
#  [[4, 0], [5, 0]],
#  [[4, 0], [6, 0, 1]],
#  [[4, 0], [8, 1]],
#  [[4, 1], [6, 1]],
#  [[4, 1], [8, 0]],
#  [[5, 0], [7, 0, 1]],
#  [[5, 0], [9, 0, 1]],
#  [[5, 1], [6, 1]],
#  [[5, 1], [9, 0, 2]],
#  [[5, 1], [13, 1]],
#  [[6, 0], [7, 0]],
#  [[6, 0], [8, 0]],
#  [[6, 0], [10, 0, 1]],
#  [[6, 0], 14],
#  [[6, 1], [10, 0, 2]],
#  [[6, 1], 14],
#  [[6, 2], [7, 2]],
#  [[6, 2], [8, 1]],
#  [[6, 2], [10, 1]],
#  [[7, 0], [9, 0]],
#  [[7, 0], [11, 0]],
#  [[7, 0], 15],
#  [[7, 1], [8, 0]],
#  [[7, 1], [9, 0]],
#  [[7, 1], [11, 1]],
#  [[7, 2], [9, 1, 2]],
#  [[7, 2], [11, 0, 1]],
#  [[7, 2], 15],
#  [[8, 0], [10, 0]],
#  [[8, 0], [12, 1]],
#  [[8, 1], [9, 1]],
#  [[8, 1], [10, 2]],
# ...

# %%
ops
# Out:
# ([[0, 1, 1, 1],
#   [0, 2, 1, 2],
#   [0, 3, 1, 3],
#   [0, 4, 1, 5],
#   [0, 5, 1, 7],
#   [0, 6, 1, 9],
#   [0, 7, 1, 12],
#   [0, 10, 1, 20],
#   [0, 12, 1, 25],
#   [0, 13, 1, 27],
#   [0, 14, 1, 29],
#   [1, 2, 2, 3, 4],
#   [1, 3, 1, 6],
#   [1, 4, 2, 7, 8],
#   [1, 5, 1, 10],
#   [1, 6, 2, 12, 13],
#   [1, 7, 1, 15],
#   [1, 8, 1, 17],
#   [1, 9, 1, 20],
#   [1, 12, 1, 27],
#   [1, 14, 1, 30],
#   [1, 15, 1, 31],
#   [2, 1, 1, 3],
#   [2, 2, 1, 6],
#   [2, 4, 3, 9, 10, 11],
#   [2, 5, 2, 12, 14],
#   [2, 6, 2, 15, 16],
#   [2, 7, 1, 18],
#   [2, 8, 1, 21],
#   [2, 9, 1, 23],
#   [2, 10, 1, 25],
#   [2, 11, 1, 27],
#   [2, 12, 1, 29],
#   [3, 2, 1, 8],
#   [3, 3, 1, 10],
#   [3, 4, 2, 12, 14],
#   [3, 6, 3, 17, 18, 19],
#   [3, 7, 2, 20, 22],
#   [3, 8, 2, 23, 24],
#   [3, 9, 1, 26],
#   [3, 10, 2, 27, 28],
#   [3, 11, 1, 29],
#   [3, 12, 1, 30],
#   [3, 13, 1, 31],
#   [4, 1, 1, 6],
#   [4, 2, 1, 8],
#   [4, 3, 1, 10],
#   [4, 4, 1, 13],
#   [4, 5, 1, 15],
#   [4, 6, 1, 17],
# ...
