# %%
import json

def generate_cw_json(cw):
    cw_json = {
      cw: {
        cw: {
          f"./Adams res {cw} 160": {
            "cmd": f"nohup ./Adams res {cw} 160 >> {cw}.out 2>&1 &"
          },
          f"./Adams prod_mod {cw} S0 160": {
            "priority": 99,
            "cmd": f"nohup ./Adams prod_mod {cw} S0 160 >> {cw}_prod.out 2>&1 &",
            "pre": [
              f"./Adams res {cw} 160"
            ]
          },
          f"./Adams export_mod {cw} S0 160": {
            "cmd": f"./Adams export_mod {cw} S0 160",
            "pre": [
              f"./Adams prod_mod {cw} S0 160"
            ]
          },
          f"cp {cw}_AdamsSS.db AdamsSS/": {
            "cmd": f"cp {cw}_AdamsSS.db AdamsSS/",
            "pre": [
              "mkdir AdamsSS",
              f"./Adams export_mod {cw} S0 160"
            ]
          }
        }
      }
    }
    return cw_json

def generate_map_json(key, cw1, cw2):
    key1, key2 = key.split("__")
    if cw2 == "S0":
        map_json = {key: {"tpl": ["module__module_S0", key1]}}
    elif key2 == cw2:
        map_json = {key: {"tpl": ["module__module", key1, key2]}}
    else:
        map_json = {key: {"tpl": ["module__module_v2", key1, key2, cw2]}}
    return map_json

def remove_comments(content: str):
    return "\n".join(line.split("//")[0] for line in content.split("\n"))

with open("Adams.json", "r") as f:
    json_str = f.read()
    js = json.loads(remove_comments(json_str))

# %%
maps_json = {}
for key, value in js["maps"].items():
    maps_json |= generate_map_json(key, value["from"], value["to"])
print(json.dumps(maps_json, indent=2))

# %%
# maps_json = {}
# for i in range(4, 65-1):
#     if (i+1) & (i+2) == 0:
#         maps_json |= generate_map_json(f"RP1_{i}__RP1_{i+2}", f"RP1_{i}", f"RP1_{i+2}")
#     elif i & (i + 1) != 0:
#         maps_json |= generate_map_json(f"RP1_{i}__RP1_{i+1}", f"RP1_{i}", f"RP1_{i+1}")

# maps_json = {}
# for i in range(3, 65):
#         maps_json |= generate_map_json(f"RP{i}_256__RP{i+1}_256", f"RP{i}_256", f"RP{i+1}_256")

maps_json = {}
for i in range(2, 65+1):
    if i & (i+1) == 0:
         continue
    maps_json |= generate_map_json(f"RP{i+1}_256__RP1_{i}", f"RP{i+1}_256", f"RP1_{i}")

print(json.dumps(maps_json, indent=2))
# Out:
# {
#   "RP3_256__RP1_2": {
#     "tpl": [
#       "module__module",
#       "RP3_256",
#       "RP1_2"
#     ]
#   },
#   "RP5_256__RP1_4": {
#     "tpl": [
#       "module__module",
#       "RP5_256",
#       "RP1_4"
#     ]
#   },
#   "RP6_256__RP1_5": {
#     "tpl": [
#       "module__module",
#       "RP6_256",
#       "RP1_5"
#     ]
#   },
#   "RP7_256__RP1_6": {
#     "tpl": [
#       "module__module",
#       "RP7_256",
#       "RP1_6"
#     ]
#   },
#   "RP9_256__RP1_8": {
#     "tpl": [
#       "module__module",
#       "RP9_256",
#       "RP1_8"
#     ]
#   },
#   "RP10_256__RP1_9": {
#     "tpl": [
#       "module__module",
#       "RP10_256",
#       "RP1_9"
#     ]
#   },
#   "RP11_256__RP1_10": {
#     "tpl": [
#       "module__module",
#       "RP11_256",
#       "RP1_10"
#     ]
#   },
#   "RP12_256__RP1_11": {
#     "tpl": [
#       "module__module",
#       "RP12_256",
#       "RP1_11"
#     ]
#   },
#   "RP13_256__RP1_12": {
#     "tpl": [
#       "module__module",
#       "RP13_256",
#       "RP1_12"
#     ]
#   },
#   "RP14_256__RP1_13": {
#     "tpl": [
#       "module__module",
#       "RP14_256",
#       "RP1_13"
#     ]
#   },
#   "RP15_256__RP1_14": {
#     "tpl": [
#       "module__module",
#       "RP15_256",
#       "RP1_14"
#     ]
#   },
#   "RP17_256__RP1_16": {
#     "tpl": [
#       "module__module",
#       "RP17_256",
#       "RP1_16"
#     ]
#   },
#   "RP18_256__RP1_17": {
#     "tpl": [
#       "module__module",
#       "RP18_256",
#       "RP1_17"
#     ]
#   },
#   "RP19_256__RP1_18": {
#     "tpl": [
#       "module__module",
#       "RP19_256",
#       "RP1_18"
#     ]
#   },
#   "RP20_256__RP1_19": {
#     "tpl": [
#       "module__module",
#       "RP20_256",
#       "RP1_19"
#     ]
#   },
#   "RP21_256__RP1_20": {
#     "tpl": [
#       "module__module",
#       "RP21_256",
#       "RP1_20"
#     ]
#   },
#   "RP22_256__RP1_21": {
#     "tpl": [
#       "module__module",
#       "RP22_256",
#       "RP1_21"
#     ]
#   },
#   "RP23_256__RP1_22": {
#     "tpl": [
#       "module__module",
#       "RP23_256",
#       "RP1_22"
#     ]
#   },
#   "RP24_256__RP1_23": {
#     "tpl": [
#       "module__module",
#       "RP24_256",
#       "RP1_23"
#     ]
#   },
#   "RP25_256__RP1_24": {
#     "tpl": [
#       "module__module",
#       "RP25_256",
#       "RP1_24"
#     ]
#   },
#   "RP26_256__RP1_25": {
#     "tpl": [
#       "module__module",
#       "RP26_256",
#       "RP1_25"
#     ]
#   },
#   "RP27_256__RP1_26": {
#     "tpl": [
#       "module__module",
#       "RP27_256",
#       "RP1_26"
#     ]
#   },
#   "RP28_256__RP1_27": {
#     "tpl": [
#       "module__module",
#       "RP28_256",
#       "RP1_27"
#     ]
#   },
#   "RP29_256__RP1_28": {
#     "tpl": [
#       "module__module",
#       "RP29_256",
#       "RP1_28"
#     ]
#   },
#   "RP30_256__RP1_29": {
#     "tpl": [
#       "module__module",
#       "RP30_256",
#       "RP1_29"
#     ]
#   },
#   "RP31_256__RP1_30": {
#     "tpl": [
#       "module__module",
#       "RP31_256",
#       "RP1_30"
#     ]
#   },
#   "RP33_256__RP1_32": {
#     "tpl": [
#       "module__module",
#       "RP33_256",
#       "RP1_32"
#     ]
#   },
#   "RP34_256__RP1_33": {
#     "tpl": [
#       "module__module",
#       "RP34_256",
#       "RP1_33"
#     ]
#   },
#   "RP35_256__RP1_34": {
#     "tpl": [
#       "module__module",
#       "RP35_256",
#       "RP1_34"
#     ]
#   },
#   "RP36_256__RP1_35": {
#     "tpl": [
#       "module__module",
#       "RP36_256",
#       "RP1_35"
#     ]
#   },
#   "RP37_256__RP1_36": {
#     "tpl": [
#       "module__module",
#       "RP37_256",
#       "RP1_36"
#     ]
#   },
#   "RP38_256__RP1_37": {
#     "tpl": [
#       "module__module",
#       "RP38_256",
#       "RP1_37"
#     ]
#   },
#   "RP39_256__RP1_38": {
#     "tpl": [
#       "module__module",
#       "RP39_256",
#       "RP1_38"
#     ]
#   },
#   "RP40_256__RP1_39": {
#     "tpl": [
#       "module__module",
#       "RP40_256",
#       "RP1_39"
#     ]
#   },
#   "RP41_256__RP1_40": {
#     "tpl": [
#       "module__module",
#       "RP41_256",
#       "RP1_40"
#     ]
#   },
#   "RP42_256__RP1_41": {
#     "tpl": [
#       "module__module",
#       "RP42_256",
#       "RP1_41"
#     ]
#   },
#   "RP43_256__RP1_42": {
#     "tpl": [
#       "module__module",
#       "RP43_256",
#       "RP1_42"
#     ]
#   },
#   "RP44_256__RP1_43": {
#     "tpl": [
#       "module__module",
#       "RP44_256",
#       "RP1_43"
#     ]
#   },
#   "RP45_256__RP1_44": {
#     "tpl": [
#       "module__module",
#       "RP45_256",
#       "RP1_44"
#     ]
#   },
#   "RP46_256__RP1_45": {
#     "tpl": [
#       "module__module",
#       "RP46_256",
#       "RP1_45"
#     ]
#   },
#   "RP47_256__RP1_46": {
#     "tpl": [
#       "module__module",
#       "RP47_256",
#       "RP1_46"
#     ]
#   },
#   "RP48_256__RP1_47": {
#     "tpl": [
#       "module__module",
#       "RP48_256",
#       "RP1_47"
#     ]
#   },
#   "RP49_256__RP1_48": {
#     "tpl": [
#       "module__module",
#       "RP49_256",
#       "RP1_48"
#     ]
#   },
#   "RP50_256__RP1_49": {
#     "tpl": [
#       "module__module",
#       "RP50_256",
#       "RP1_49"
#     ]
#   },
#   "RP51_256__RP1_50": {
#     "tpl": [
#       "module__module",
#       "RP51_256",
#       "RP1_50"
#     ]
#   },
#   "RP52_256__RP1_51": {
#     "tpl": [
#       "module__module",
#       "RP52_256",
#       "RP1_51"
#     ]
#   },
#   "RP53_256__RP1_52": {
#     "tpl": [
#       "module__module",
#       "RP53_256",
#       "RP1_52"
#     ]
#   },
#   "RP54_256__RP1_53": {
#     "tpl": [
#       "module__module",
#       "RP54_256",
#       "RP1_53"
#     ]
#   },
#   "RP55_256__RP1_54": {
#     "tpl": [
#       "module__module",
#       "RP55_256",
#       "RP1_54"
#     ]
#   },
#   "RP56_256__RP1_55": {
#     "tpl": [
#       "module__module",
#       "RP56_256",
#       "RP1_55"
#     ]
#   },
#   "RP57_256__RP1_56": {
#     "tpl": [
#       "module__module",
#       "RP57_256",
#       "RP1_56"
#     ]
#   },
#   "RP58_256__RP1_57": {
#     "tpl": [
#       "module__module",
#       "RP58_256",
#       "RP1_57"
#     ]
#   },
#   "RP59_256__RP1_58": {
#     "tpl": [
#       "module__module",
#       "RP59_256",
#       "RP1_58"
#     ]
#   },
#   "RP60_256__RP1_59": {
#     "tpl": [
#       "module__module",
#       "RP60_256",
#       "RP1_59"
#     ]
#   },
#   "RP61_256__RP1_60": {
#     "tpl": [
#       "module__module",
#       "RP61_256",
#       "RP1_60"
#     ]
#   },
#   "RP62_256__RP1_61": {
#     "tpl": [
#       "module__module",
#       "RP62_256",
#       "RP1_61"
#     ]
#   },
#   "RP63_256__RP1_62": {
#     "tpl": [
#       "module__module",
#       "RP63_256",
#       "RP1_62"
#     ]
#   },
#   "RP65_256__RP1_64": {
#     "tpl": [
#       "module__module",
#       "RP65_256",
#       "RP1_64"
#     ]
#   },
#   "RP66_256__RP1_65": {
#     "tpl": [
#       "module__module",
#       "RP66_256",
#       "RP1_65"
#     ]
#   }
# }

# %%
print(json.dumps(generate_map_json(f"RP1_{64}__RP1_{256}", f"RP1_{64}", f"RP1_{256}"), indent=2))

# %%
import json

def remove_comments(content: str):
    return "\n".join(line.split("//")[0] for line in content.split("\n"))

with open("Adams.json", "r") as f:
    json_str = f.read()
    js = json.loads(remove_comments(json_str))



maps_json = {}
for key, value in js["CW_complexes"].items():
    maps_json |= generate_cw_json(key)
print(json.dumps(maps_json, indent=2))

# %%
import json

def remove_comments(content: str):
    return "\n".join(line.split("//")[0] for line in content.split("\n"))

with open("Adams.json", "r") as f:
    json_str = f.read()
    js = json.loads(remove_comments(json_str))

def generate_cw_json(cw):
    cw_json = {
      cw: {"tpl": ["module", f"{cw}", "160"]}
    }
    return cw_json

maps_json = {}
for i in range(3, 66):
    # if i & (i+1) == 0:
    #     continue
    maps_json |= generate_cw_json(f"RP{i}_{256}")
print(json.dumps(maps_json))
# Out:
# {"RP3_256": {"tpl": ["module", "RP3_256", "160"]}, "RP4_256": {"tpl": ["module", "RP4_256", "160"]}, "RP5_256": {"tpl": ["module", "RP5_256", "160"]}, "RP6_256": {"tpl": ["module", "RP6_256", "160"]}, "RP7_256": {"tpl": ["module", "RP7_256", "160"]}, "RP8_256": {"tpl": ["module", "RP8_256", "160"]}, "RP9_256": {"tpl": ["module", "RP9_256", "160"]}, "RP10_256": {"tpl": ["module", "RP10_256", "160"]}, "RP11_256": {"tpl": ["module", "RP11_256", "160"]}, "RP12_256": {"tpl": ["module", "RP12_256", "160"]}, "RP13_256": {"tpl": ["module", "RP13_256", "160"]}, "RP14_256": {"tpl": ["module", "RP14_256", "160"]}, "RP15_256": {"tpl": ["module", "RP15_256", "160"]}, "RP16_256": {"tpl": ["module", "RP16_256", "160"]}, "RP17_256": {"tpl": ["module", "RP17_256", "160"]}, "R